# %% [markdown]
# # Brute Force Automated Feature Selection
# ## Experiments with Tree-based Scikit-learn models | Quantitative Analysis
#
# **Objective**: The primary objective of this notebook is to perform experimentation with the tree-based models for multi-step ahead forecasting with *Quant* features.

# %%
import sys
import os

# Get the directory of the current notebook
notebook_dir = os.path.dirname(os.path.abspath("__file__"))  # Use __file__ for portability

# Move up one level to the project root
project_root = os.path.abspath(os.path.join(notebook_dir, ".."))

# Change working directory
os.chdir(project_root)

# Verify the change
print(os.getcwd())
# Out:
# /home/michel/projects/tree-based-forecasting-boilerplate

# %%
# %load_ext autoreload
# %autoreload 2

from statsmodels.tsa.seasonal import STL, seasonal_decompose
from sklearn.preprocessing import MinMaxScaler, RobustScaler

from scripts.run_wfv import *
from src.models.train_model import *
from src.models.evaluate_model import *
from src.models.predict_model import *
from src.visualization.data_viz import *

# %%
df = pd.read_csv(os.path.join('./data/processed', 'processed_df.csv'), parse_dates=["DATE"])
df = df.set_index("DATE")
df.head()
# Out:
#                TICKER   CLOSE  DAY_OF_MONTH  DAY_OF_WEEK  WEEK_OF_MONTH  \
# DATE
# 2019-07-05  BOVA11.SA  100.27             5            4              1
# 2019-07-08  BOVA11.SA  100.56             8            0              2
# 2019-07-10  BOVA11.SA  101.96            10            2              2
# 2019-07-11  BOVA11.SA  101.21            11            3              2
# 2019-07-12  BOVA11.SA  100.05            12            4              2
#
#             MONTH  QUARTER  YEAR  CLOSE_LAG_1  CLOSE_LAG_2  CLOSE_MA_3
# DATE
# 2019-07-05      7        3  2019       100.00        98.32      98.363
# 2019-07-08      7        3  2019       100.27       100.00      99.530
# 2019-07-10      7        3  2019       100.56       100.27     100.277
# 2019-07-11      7        3  2019       101.96       100.56     100.930
# 2019-07-12      7        3  2019       101.21       101.96     101.243

# %%
df = df[df['TICKER'] == 'BOVA11.SA']

# %%
import numpy as np
from sklearn.model_selection import cross_val_score
from itertools import chain, combinations

def automated_feature_selection(model, features, sample_ratio, cv=5, scoring='accuracy'):
    """
    Performs automated feature selection by iterating through feature combinations and evaluating model performance.

    Args:
        model: A scikit-learn model instance.
        features: A list of feature names.
        sample_ratio: A float between 0 and 1, representing the proportion of features to sample.
        cv: Number of cross-validation folds (default=5).
        scoring: The metric used for evaluating the model (default='accuracy').

    Returns:
        A tuple containing:
            - A dictionary mapping feature combinations to their average cross-validation scores.
            - A list of the feature combination with the best (lowest) average cross-validation score.
    """
    
    num_features_to_sample = int(len(features) * sample_ratio)
    sampled_features = np.random.choice(features, size=num_features_to_sample, replace=False).tolist()
    print(f'Sampled features: {sampled_features}')

    # Create powerset of feature combinations
    powerset = chain.from_iterable(combinations(sampled_features, r) for r in range(1, len(sampled_features) + 1))
    
    results = {}  # Dictionary to store results
    best_score = float('inf')  # Initialize best score as infinity
    best_features = []

    for idx, feature_set in enumerate(powerset):
        print(f"Testing {idx}th feature set: {feature_set}")
        X_selected = X[list(feature_set)]  # Assume you have a DataFrame X with your features
        scores = cross_val_score(model, X_selected, y, cv=cv, scoring=scoring)  
        avg_score = np.mean(scores)
        results[feature_set] = avg_score

        if avg_score < best_score:
            best_score = avg_score
            best_features = list(feature_set)

    return results, best_features

# %%
from sklearn.linear_model import LinearRegression

X,y = df.drop(columns=["CLOSE", "TICKER"]), df['CLOSE']
# Assuming X is your feature matrix and y is your target variable
results, best_features = automated_feature_selection(LinearRegression(), X.columns.tolist(), 1.0, scoring='neg_mean_squared_log_error')
print("Best Features:", best_features)
print("All Results:", results)
# Out:
# Sampled features: ['QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH']
# Testing 0th feature set: ('QUARTER',)
# Testing 1th feature set: ('CLOSE_LAG_2',)
# Testing 2th feature set: ('DAY_OF_WEEK',)
# Testing 3th feature set: ('CLOSE_LAG_1',)
# Testing 4th feature set: ('CLOSE_MA_3',)
# Testing 5th feature set: ('YEAR',)
# Testing 6th feature set: ('MONTH',)
# Testing 7th feature set: ('DAY_OF_MONTH',)
# Testing 8th feature set: ('WEEK_OF_MONTH',)
# Testing 9th feature set: ('QUARTER', 'CLOSE_LAG_2')
# Testing 10th feature set: ('QUARTER', 'DAY_OF_WEEK')
# Testing 11th feature set: ('QUARTER', 'CLOSE_LAG_1')
# Testing 12th feature set: ('QUARTER', 'CLOSE_MA_3')
# Testing 13th feature set: ('QUARTER', 'YEAR')
# Testing 14th feature set: ('QUARTER', 'MONTH')
# Testing 15th feature set: ('QUARTER', 'DAY_OF_MONTH')
# Testing 16th feature set: ('QUARTER', 'WEEK_OF_MONTH')
# Testing 17th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK')
# Testing 18th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1')
# Testing 19th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3')
# Testing 20th feature set: ('CLOSE_LAG_2', 'YEAR')
# Testing 21th feature set: ('CLOSE_LAG_2', 'MONTH')
# Testing 22th feature set: ('CLOSE_LAG_2', 'DAY_OF_MONTH')
# Testing 23th feature set: ('CLOSE_LAG_2', 'WEEK_OF_MONTH')
# Testing 24th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1')
# Testing 25th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3')
# Testing 26th feature set: ('DAY_OF_WEEK', 'YEAR')
# Testing 27th feature set: ('DAY_OF_WEEK', 'MONTH')
# Testing 28th feature set: ('DAY_OF_WEEK', 'DAY_OF_MONTH')
# Testing 29th feature set: ('DAY_OF_WEEK', 'WEEK_OF_MONTH')
# Testing 30th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3')
# Testing 31th feature set: ('CLOSE_LAG_1', 'YEAR')
# Testing 32th feature set: ('CLOSE_LAG_1', 'MONTH')
# Testing 33th feature set: ('CLOSE_LAG_1', 'DAY_OF_MONTH')
# Testing 34th feature set: ('CLOSE_LAG_1', 'WEEK_OF_MONTH')
# Testing 35th feature set: ('CLOSE_MA_3', 'YEAR')
# Testing 36th feature set: ('CLOSE_MA_3', 'MONTH')
# Testing 37th feature set: ('CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 38th feature set: ('CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 39th feature set: ('YEAR', 'MONTH')
# Testing 40th feature set: ('YEAR', 'DAY_OF_MONTH')
# Testing 41th feature set: ('YEAR', 'WEEK_OF_MONTH')
# Testing 42th feature set: ('MONTH', 'DAY_OF_MONTH')
# Testing 43th feature set: ('MONTH', 'WEEK_OF_MONTH')
# Testing 44th feature set: ('DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 45th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK')
# Testing 46th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1')
# Testing 47th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3')
# Testing 48th feature set: ('QUARTER', 'CLOSE_LAG_2', 'YEAR')
# Testing 49th feature set: ('QUARTER', 'CLOSE_LAG_2', 'MONTH')
# Testing 50th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_MONTH')
# Testing 51th feature set: ('QUARTER', 'CLOSE_LAG_2', 'WEEK_OF_MONTH')
# Testing 52th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1')
# Testing 53th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3')
# Testing 54th feature set: ('QUARTER', 'DAY_OF_WEEK', 'YEAR')
# Testing 55th feature set: ('QUARTER', 'DAY_OF_WEEK', 'MONTH')
# Testing 56th feature set: ('QUARTER', 'DAY_OF_WEEK', 'DAY_OF_MONTH')
# Testing 57th feature set: ('QUARTER', 'DAY_OF_WEEK', 'WEEK_OF_MONTH')
# Testing 58th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3')
# Testing 59th feature set: ('QUARTER', 'CLOSE_LAG_1', 'YEAR')
# Testing 60th feature set: ('QUARTER', 'CLOSE_LAG_1', 'MONTH')
# Testing 61th feature set: ('QUARTER', 'CLOSE_LAG_1', 'DAY_OF_MONTH')
# Testing 62th feature set: ('QUARTER', 'CLOSE_LAG_1', 'WEEK_OF_MONTH')
# Testing 63th feature set: ('QUARTER', 'CLOSE_MA_3', 'YEAR')
# Testing 64th feature set: ('QUARTER', 'CLOSE_MA_3', 'MONTH')
# Testing 65th feature set: ('QUARTER', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 66th feature set: ('QUARTER', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 67th feature set: ('QUARTER', 'YEAR', 'MONTH')
# Testing 68th feature set: ('QUARTER', 'YEAR', 'DAY_OF_MONTH')
# Testing 69th feature set: ('QUARTER', 'YEAR', 'WEEK_OF_MONTH')
# Testing 70th feature set: ('QUARTER', 'MONTH', 'DAY_OF_MONTH')
# Testing 71th feature set: ('QUARTER', 'MONTH', 'WEEK_OF_MONTH')
# Testing 72th feature set: ('QUARTER', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 73th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1')
# Testing 74th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3')
# Testing 75th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR')
# Testing 76th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'MONTH')
# Testing 77th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'DAY_OF_MONTH')
# Testing 78th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'WEEK_OF_MONTH')
# Testing 79th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3')
# Testing 80th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR')
# Testing 81th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'MONTH')
# Testing 82th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'DAY_OF_MONTH')
# Testing 83th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'WEEK_OF_MONTH')
# Testing 84th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR')
# Testing 85th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'MONTH')
# Testing 86th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 87th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 88th feature set: ('CLOSE_LAG_2', 'YEAR', 'MONTH')
# Testing 89th feature set: ('CLOSE_LAG_2', 'YEAR', 'DAY_OF_MONTH')
# Testing 90th feature set: ('CLOSE_LAG_2', 'YEAR', 'WEEK_OF_MONTH')
# Testing 91th feature set: ('CLOSE_LAG_2', 'MONTH', 'DAY_OF_MONTH')
# Testing 92th feature set: ('CLOSE_LAG_2', 'MONTH', 'WEEK_OF_MONTH')
# Testing 93th feature set: ('CLOSE_LAG_2', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 94th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3')
# Testing 95th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR')
# Testing 96th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH')
# Testing 97th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'DAY_OF_MONTH')
# Testing 98th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'WEEK_OF_MONTH')
# Testing 99th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR')
# Testing 100th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH')
# Testing 101th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 102th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 103th feature set: ('DAY_OF_WEEK', 'YEAR', 'MONTH')
# Testing 104th feature set: ('DAY_OF_WEEK', 'YEAR', 'DAY_OF_MONTH')
# Testing 105th feature set: ('DAY_OF_WEEK', 'YEAR', 'WEEK_OF_MONTH')
# Testing 106th feature set: ('DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH')
# Testing 107th feature set: ('DAY_OF_WEEK', 'MONTH', 'WEEK_OF_MONTH')
# Testing 108th feature set: ('DAY_OF_WEEK', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 109th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR')
# Testing 110th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH')
# Testing 111th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 112th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 113th feature set: ('CLOSE_LAG_1', 'YEAR', 'MONTH')
# Testing 114th feature set: ('CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH')
# Testing 115th feature set: ('CLOSE_LAG_1', 'YEAR', 'WEEK_OF_MONTH')
# Testing 116th feature set: ('CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH')
# Testing 117th feature set: ('CLOSE_LAG_1', 'MONTH', 'WEEK_OF_MONTH')
# Testing 118th feature set: ('CLOSE_LAG_1', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 119th feature set: ('CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 120th feature set: ('CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 121th feature set: ('CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 122th feature set: ('CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 123th feature set: ('CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 124th feature set: ('CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 125th feature set: ('YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 126th feature set: ('YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 127th feature set: ('YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 128th feature set: ('MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 129th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1')
# Testing 130th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3')
# Testing 131th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR')
# Testing 132th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'MONTH')
# Testing 133th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'DAY_OF_MONTH')
# Testing 134th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'WEEK_OF_MONTH')
# Testing 135th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3')
# Testing 136th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR')
# Testing 137th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'MONTH')
# Testing 138th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'DAY_OF_MONTH')
# Testing 139th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'WEEK_OF_MONTH')
# Testing 140th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR')
# Testing 141th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'MONTH')
# Testing 142th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 143th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 144th feature set: ('QUARTER', 'CLOSE_LAG_2', 'YEAR', 'MONTH')
# Testing 145th feature set: ('QUARTER', 'CLOSE_LAG_2', 'YEAR', 'DAY_OF_MONTH')
# Testing 146th feature set: ('QUARTER', 'CLOSE_LAG_2', 'YEAR', 'WEEK_OF_MONTH')
# Testing 147th feature set: ('QUARTER', 'CLOSE_LAG_2', 'MONTH', 'DAY_OF_MONTH')
# Testing 148th feature set: ('QUARTER', 'CLOSE_LAG_2', 'MONTH', 'WEEK_OF_MONTH')
# Testing 149th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 150th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3')
# Testing 151th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR')
# Testing 152th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH')
# Testing 153th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'DAY_OF_MONTH')
# Testing 154th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'WEEK_OF_MONTH')
# Testing 155th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR')
# Testing 156th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH')
# Testing 157th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 158th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 159th feature set: ('QUARTER', 'DAY_OF_WEEK', 'YEAR', 'MONTH')
# Testing 160th feature set: ('QUARTER', 'DAY_OF_WEEK', 'YEAR', 'DAY_OF_MONTH')
# Testing 161th feature set: ('QUARTER', 'DAY_OF_WEEK', 'YEAR', 'WEEK_OF_MONTH')
# Testing 162th feature set: ('QUARTER', 'DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH')
# Testing 163th feature set: ('QUARTER', 'DAY_OF_WEEK', 'MONTH', 'WEEK_OF_MONTH')
# Testing 164th feature set: ('QUARTER', 'DAY_OF_WEEK', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 165th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR')
# Testing 166th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH')
# Testing 167th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 168th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 169th feature set: ('QUARTER', 'CLOSE_LAG_1', 'YEAR', 'MONTH')
# Testing 170th feature set: ('QUARTER', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH')
# Testing 171th feature set: ('QUARTER', 'CLOSE_LAG_1', 'YEAR', 'WEEK_OF_MONTH')
# Testing 172th feature set: ('QUARTER', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH')
# Testing 173th feature set: ('QUARTER', 'CLOSE_LAG_1', 'MONTH', 'WEEK_OF_MONTH')
# Testing 174th feature set: ('QUARTER', 'CLOSE_LAG_1', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 175th feature set: ('QUARTER', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 176th feature set: ('QUARTER', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 177th feature set: ('QUARTER', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 178th feature set: ('QUARTER', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 179th feature set: ('QUARTER', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 180th feature set: ('QUARTER', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 181th feature set: ('QUARTER', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 182th feature set: ('QUARTER', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 183th feature set: ('QUARTER', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 184th feature set: ('QUARTER', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 185th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3')
# Testing 186th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR')
# Testing 187th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH')
# Testing 188th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'DAY_OF_MONTH')
# Testing 189th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'WEEK_OF_MONTH')
# Testing 190th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR')
# Testing 191th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH')
# Testing 192th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 193th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 194th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'MONTH')
# Testing 195th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'DAY_OF_MONTH')
# Testing 196th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'WEEK_OF_MONTH')
# Testing 197th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH')
# Testing 198th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'MONTH', 'WEEK_OF_MONTH')
# Testing 199th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 200th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR')
# Testing 201th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH')
# Testing 202th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 203th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 204th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'MONTH')
# Testing 205th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH')
# Testing 206th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'WEEK_OF_MONTH')
# Testing 207th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH')
# Testing 208th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'MONTH', 'WEEK_OF_MONTH')
# Testing 209th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 210th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 211th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 212th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 213th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 214th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 215th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 216th feature set: ('CLOSE_LAG_2', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 217th feature set: ('CLOSE_LAG_2', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 218th feature set: ('CLOSE_LAG_2', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 219th feature set: ('CLOSE_LAG_2', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 220th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR')
# Testing 221th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH')
# Testing 222th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 223th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 224th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH')
# Testing 225th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH')
# Testing 226th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'WEEK_OF_MONTH')
# Testing 227th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH')
# Testing 228th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'WEEK_OF_MONTH')
# Testing 229th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 230th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 231th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 232th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 233th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 234th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 235th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 236th feature set: ('DAY_OF_WEEK', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 237th feature set: ('DAY_OF_WEEK', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 238th feature set: ('DAY_OF_WEEK', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 239th feature set: ('DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 240th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 241th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 242th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 243th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 244th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 245th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 246th feature set: ('CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 247th feature set: ('CLOSE_LAG_1', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 248th feature set: ('CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 249th feature set: ('CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 250th feature set: ('CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 251th feature set: ('CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 252th feature set: ('CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 253th feature set: ('CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 254th feature set: ('YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 255th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3')
# Testing 256th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR')
# Testing 257th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH')
# Testing 258th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'DAY_OF_MONTH')
# Testing 259th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'WEEK_OF_MONTH')
# Testing 260th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR')
# Testing 261th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH')
# Testing 262th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 263th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 264th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'MONTH')
# Testing 265th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'DAY_OF_MONTH')
# Testing 266th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'WEEK_OF_MONTH')
# Testing 267th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH')
# Testing 268th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'MONTH', 'WEEK_OF_MONTH')
# Testing 269th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 270th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR')
# Testing 271th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH')
# Testing 272th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 273th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 274th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'MONTH')
# Testing 275th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH')
# Testing 276th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'WEEK_OF_MONTH')
# Testing 277th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH')
# Testing 278th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'MONTH', 'WEEK_OF_MONTH')
# Testing 279th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 280th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 281th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 282th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 283th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 284th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 285th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 286th feature set: ('QUARTER', 'CLOSE_LAG_2', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 287th feature set: ('QUARTER', 'CLOSE_LAG_2', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 288th feature set: ('QUARTER', 'CLOSE_LAG_2', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 289th feature set: ('QUARTER', 'CLOSE_LAG_2', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 290th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR')
# Testing 291th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH')
# Testing 292th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 293th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 294th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH')
# Testing 295th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH')
# Testing 296th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'WEEK_OF_MONTH')
# Testing 297th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH')
# Testing 298th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'WEEK_OF_MONTH')
# Testing 299th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 300th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 301th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 302th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 303th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 304th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 305th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 306th feature set: ('QUARTER', 'DAY_OF_WEEK', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 307th feature set: ('QUARTER', 'DAY_OF_WEEK', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 308th feature set: ('QUARTER', 'DAY_OF_WEEK', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 309th feature set: ('QUARTER', 'DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 310th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 311th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 312th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 313th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 314th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 315th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 316th feature set: ('QUARTER', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 317th feature set: ('QUARTER', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 318th feature set: ('QUARTER', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 319th feature set: ('QUARTER', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 320th feature set: ('QUARTER', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 321th feature set: ('QUARTER', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 322th feature set: ('QUARTER', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 323th feature set: ('QUARTER', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 324th feature set: ('QUARTER', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 325th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR')
# Testing 326th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH')
# Testing 327th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 328th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 329th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH')
# Testing 330th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH')
# Testing 331th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'WEEK_OF_MONTH')
# Testing 332th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH')
# Testing 333th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'WEEK_OF_MONTH')
# Testing 334th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 335th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 336th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 337th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 338th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 339th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 340th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 341th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 342th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 343th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 344th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 345th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 346th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 347th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 348th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 349th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 350th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 351th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 352th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 353th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 354th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 355th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 356th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 357th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 358th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 359th feature set: ('CLOSE_LAG_2', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 360th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 361th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 362th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 363th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 364th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 365th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 366th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 367th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 368th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 369th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 370th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 371th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 372th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 373th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 374th feature set: ('DAY_OF_WEEK', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 375th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 376th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 377th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 378th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 379th feature set: ('CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 380th feature set: ('CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 381th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR')
# Testing 382th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH')
# Testing 383th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH')
# Testing 384th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'WEEK_OF_MONTH')
# Testing 385th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH')
# Testing 386th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH')
# Testing 387th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'WEEK_OF_MONTH')
# Testing 388th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH')
# Testing 389th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'WEEK_OF_MONTH')
# Testing 390th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 391th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 392th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 393th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 394th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 395th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 396th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 397th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 398th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 399th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 400th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 401th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 402th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 403th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 404th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 405th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 406th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 407th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 408th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 409th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 410th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 411th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 412th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 413th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 414th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 415th feature set: ('QUARTER', 'CLOSE_LAG_2', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 416th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 417th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 418th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 419th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 420th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 421th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 422th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 423th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 424th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 425th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 426th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 427th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 428th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 429th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 430th feature set: ('QUARTER', 'DAY_OF_WEEK', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 431th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 432th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 433th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 434th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 435th feature set: ('QUARTER', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 436th feature set: ('QUARTER', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 437th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 438th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 439th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 440th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 441th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 442th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 443th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 444th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 445th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 446th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 447th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 448th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 449th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 450th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 451th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 452th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 453th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 454th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 455th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 456th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 457th feature set: ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 458th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 459th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 460th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 461th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 462th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 463th feature set: ('DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 464th feature set: ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 465th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH')
# Testing 466th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH')
# Testing 467th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH')
# Testing 468th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH')
# Testing 469th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH')
# Testing 470th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 471th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 472th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 473th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 474th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 475th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 476th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 477th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 478th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 479th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 480th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 481th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 482th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 483th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 484th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 485th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 486th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 487th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 488th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 489th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 490th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 491th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 492th feature set: ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 493th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 494th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 495th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 496th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 497th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 498th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 499th feature set: ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 500th feature set: ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 501th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH')
# Testing 502th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH')
# Testing 503th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 504th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 505th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 506th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 507th feature set: ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 508th feature set: ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 509th feature set: ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Testing 510th feature set: ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH')
# Best Features: ['QUARTER', 'DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH']
# All Results: {('QUARTER',): -0.016149184479824212, ('CLOSE_LAG_2',): -0.00045121617284803775, ('DAY_OF_WEEK',): -0.015683079957963787, ('CLOSE_LAG_1',): -0.000270046655622246, ('CLOSE_MA_3',): -0.00035767186415635075, ('YEAR',): -0.0116681643260659, ('MONTH',): -0.016073870363970493, ('DAY_OF_MONTH',): -0.015681585334499638, ('WEEK_OF_MONTH',): -0.015680684116753815, ('QUARTER', 'CLOSE_LAG_2'): -0.00045175221861210306, ('QUARTER', 'DAY_OF_WEEK'): -0.016151603329242325, ('QUARTER', 'CLOSE_LAG_1'): -0.0002702060311884637, ('QUARTER', 'CLOSE_MA_3'): -0.00035762035994180657, ('QUARTER', 'YEAR'): -0.01217207231194341, ('QUARTER', 'MONTH'): -0.016192026579962583, ('QUARTER', 'DAY_OF_MONTH'): -0.016149946245824227, ('QUARTER', 'WEEK_OF_MONTH'): -0.016149037452838154, ('CLOSE_LAG_2', 'DAY_OF_WEEK'): -0.00045139624348056434, ('CLOSE_LAG_2', 'CLOSE_LAG_1'): -0.0002660634415149779, ('CLOSE_LAG_2', 'CLOSE_MA_3'): -0.000359482064895263, ('CLOSE_LAG_2', 'YEAR'): -0.0004504077553259018, ('CLOSE_LAG_2', 'MONTH'): -0.00045170778620022843, ('CLOSE_LAG_2', 'DAY_OF_MONTH'): -0.00045186402715889477, ('CLOSE_LAG_2', 'WEEK_OF_MONTH'): -0.0004515567962493906, ('DAY_OF_WEEK', 'CLOSE_LAG_1'): -0.00027011855087168477, ('DAY_OF_WEEK', 'CLOSE_MA_3'): -0.00035782431931527097, ('DAY_OF_WEEK', 'YEAR'): -0.01167019580864807, ('DAY_OF_WEEK', 'MONTH'): -0.0160759284695696, ('DAY_OF_WEEK', 'DAY_OF_MONTH'): -0.015683504728083726, ('DAY_OF_WEEK', 'WEEK_OF_MONTH'): -0.015682579491561814, ('CLOSE_LAG_1', 'CLOSE_MA_3'): -0.00026730913877131125, ('CLOSE_LAG_1', 'YEAR'): -0.00026965902377471695, ('CLOSE_LAG_1', 'MONTH'): -0.0002701362646463734, ('CLOSE_LAG_1', 'DAY_OF_MONTH'): -0.0002699369673790692, ('CLOSE_LAG_1', 'WEEK_OF_MONTH'): -0.00026969784562092794, ('CLOSE_MA_3', 'YEAR'): -0.0003582755486159526, ('CLOSE_MA_3', 'MONTH'): -0.00035779375669328206, ('CLOSE_MA_3', 'DAY_OF_MONTH'): -0.0003581742956913617, ('CLOSE_MA_3', 'WEEK_OF_MONTH'): -0.0003580676103038459, ('YEAR', 'MONTH'): -0.012075411339159655, ('YEAR', 'DAY_OF_MONTH'): -0.011669837968756114, ('YEAR', 'WEEK_OF_MONTH'): -0.011669653578121154, ('MONTH', 'DAY_OF_MONTH'): -0.016074647642645764, ('MONTH', 'WEEK_OF_MONTH'): -0.016073854306066948, ('DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.01567890375769454, ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK'): -0.00045191227922060097, ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1'): -0.00026633977434657133, ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3'): -0.00035943310926475223, ('QUARTER', 'CLOSE_LAG_2', 'YEAR'): -0.00044987838849804614, ('QUARTER', 'CLOSE_LAG_2', 'MONTH'): -0.0004525529234046868, ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_MONTH'): -0.0004523514131502735, ('QUARTER', 'CLOSE_LAG_2', 'WEEK_OF_MONTH'): -0.00045205218215376645, ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1'): -0.00027027377515592265, ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3'): -0.0003577564871092753, ('QUARTER', 'DAY_OF_WEEK', 'YEAR'): -0.01217468920266714, ('QUARTER', 'DAY_OF_WEEK', 'MONTH'): -0.016194879944508463, ('QUARTER', 'DAY_OF_WEEK', 'DAY_OF_MONTH'): -0.016152376406413392, ('QUARTER', 'DAY_OF_WEEK', 'WEEK_OF_MONTH'): -0.016151455812781112, ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3'): -0.0002676167969777176, ('QUARTER', 'CLOSE_LAG_1', 'YEAR'): -0.00026953793645294576, ('QUARTER', 'CLOSE_LAG_1', 'MONTH'): -0.0002705666844081048, ('QUARTER', 'CLOSE_LAG_1', 'DAY_OF_MONTH'): -0.0002700714623436599, ('QUARTER', 'CLOSE_LAG_1', 'WEEK_OF_MONTH'): -0.00026983641980064956, ('QUARTER', 'CLOSE_MA_3', 'YEAR'): -0.0003577598104652976, ('QUARTER', 'CLOSE_MA_3', 'MONTH'): -0.0003582652761921522, ('QUARTER', 'CLOSE_MA_3', 'DAY_OF_MONTH'): -0.00035809410465149205, ('QUARTER', 'CLOSE_MA_3', 'WEEK_OF_MONTH'): -0.00035799008787670985, ('QUARTER', 'YEAR', 'MONTH'): -0.012216696353622446, ('QUARTER', 'YEAR', 'DAY_OF_MONTH'): -0.012173604430222687, ('QUARTER', 'YEAR', 'WEEK_OF_MONTH'): -0.012173391618597268, ('QUARTER', 'MONTH', 'DAY_OF_MONTH'): -0.01619270513362705, ('QUARTER', 'MONTH', 'WEEK_OF_MONTH'): -0.016191888126154293, ('QUARTER', 'DAY ...

# %%
results
# Out:
# {('QUARTER',): -0.016149184479824212,
#  ('CLOSE_LAG_2',): -0.00045121617284803775,
#  ('DAY_OF_WEEK',): -0.015683079957963787,
#  ('CLOSE_LAG_1',): -0.000270046655622246,
#  ('CLOSE_MA_3',): -0.00035767186415635075,
#  ('YEAR',): -0.0116681643260659,
#  ('MONTH',): -0.016073870363970493,
#  ('DAY_OF_MONTH',): -0.015681585334499638,
#  ('WEEK_OF_MONTH',): -0.015680684116753815,
#  ('QUARTER', 'CLOSE_LAG_2'): -0.00045175221861210306,
#  ('QUARTER', 'DAY_OF_WEEK'): -0.016151603329242325,
#  ('QUARTER', 'CLOSE_LAG_1'): -0.0002702060311884637,
#  ('QUARTER', 'CLOSE_MA_3'): -0.00035762035994180657,
#  ('QUARTER', 'YEAR'): -0.01217207231194341,
#  ('QUARTER', 'MONTH'): -0.016192026579962583,
#  ('QUARTER', 'DAY_OF_MONTH'): -0.016149946245824227,
#  ('QUARTER', 'WEEK_OF_MONTH'): -0.016149037452838154,
#  ('CLOSE_LAG_2', 'DAY_OF_WEEK'): -0.00045139624348056434,
#  ('CLOSE_LAG_2', 'CLOSE_LAG_1'): -0.0002660634415149779,
#  ('CLOSE_LAG_2', 'CLOSE_MA_3'): -0.000359482064895263,
#  ('CLOSE_LAG_2', 'YEAR'): -0.0004504077553259018,
#  ('CLOSE_LAG_2', 'MONTH'): -0.00045170778620022843,
#  ('CLOSE_LAG_2', 'DAY_OF_MONTH'): -0.00045186402715889477,
#  ('CLOSE_LAG_2', 'WEEK_OF_MONTH'): -0.0004515567962493906,
#  ('DAY_OF_WEEK', 'CLOSE_LAG_1'): -0.00027011855087168477,
#  ('DAY_OF_WEEK', 'CLOSE_MA_3'): -0.00035782431931527097,
#  ('DAY_OF_WEEK', 'YEAR'): -0.01167019580864807,
#  ('DAY_OF_WEEK', 'MONTH'): -0.0160759284695696,
#  ('DAY_OF_WEEK', 'DAY_OF_MONTH'): -0.015683504728083726,
#  ('DAY_OF_WEEK', 'WEEK_OF_MONTH'): -0.015682579491561814,
#  ('CLOSE_LAG_1', 'CLOSE_MA_3'): -0.00026730913877131125,
#  ('CLOSE_LAG_1', 'YEAR'): -0.00026965902377471695,
#  ('CLOSE_LAG_1', 'MONTH'): -0.0002701362646463734,
#  ('CLOSE_LAG_1', 'DAY_OF_MONTH'): -0.0002699369673790692,
#  ('CLOSE_LAG_1', 'WEEK_OF_MONTH'): -0.00026969784562092794,
#  ('CLOSE_MA_3', 'YEAR'): -0.0003582755486159526,
#  ('CLOSE_MA_3', 'MONTH'): -0.00035779375669328206,
#  ('CLOSE_MA_3', 'DAY_OF_MONTH'): -0.0003581742956913617,
#  ('CLOSE_MA_3', 'WEEK_OF_MONTH'): -0.0003580676103038459,
#  ('YEAR', 'MONTH'): -0.012075411339159655,
#  ('YEAR', 'DAY_OF_MONTH'): -0.011669837968756114,
#  ('YEAR', 'WEEK_OF_MONTH'): -0.011669653578121154,
#  ('MONTH', 'DAY_OF_MONTH'): -0.016074647642645764,
#  ('MONTH', 'WEEK_OF_MONTH'): -0.016073854306066948,
#  ('DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.01567890375769454,
#  ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK'): -0.00045191227922060097,
#  ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1'): -0.00026633977434657133,
#  ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3'): -0.00035943310926475223,
#  ('QUARTER', 'CLOSE_LAG_2', 'YEAR'): -0.00044987838849804614,
#  ('QUARTER', 'CLOSE_LAG_2', 'MONTH'): -0.0004525529234046868,
#  ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_MONTH'): -0.0004523514131502735,
#  ('QUARTER', 'CLOSE_LAG_2', 'WEEK_OF_MONTH'): -0.00045205218215376645,
#  ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1'): -0.00027027377515592265,
#  ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3'): -0.0003577564871092753,
#  ('QUARTER', 'DAY_OF_WEEK', 'YEAR'): -0.01217468920266714,
#  ('QUARTER', 'DAY_OF_WEEK', 'MONTH'): -0.016194879944508463,
#  ('QUARTER', 'DAY_OF_WEEK', 'DAY_OF_MONTH'): -0.016152376406413392,
#  ('QUARTER', 'DAY_OF_WEEK', 'WEEK_OF_MONTH'): -0.016151455812781112,
#  ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3'): -0.0002676167969777176,
#  ('QUARTER', 'CLOSE_LAG_1', 'YEAR'): -0.00026953793645294576,
#  ('QUARTER', 'CLOSE_LAG_1', 'MONTH'): -0.0002705666844081048,
#  ('QUARTER', 'CLOSE_LAG_1', 'DAY_OF_MONTH'): -0.0002700714623436599,
#  ('QUARTER', 'CLOSE_LAG_1', 'WEEK_OF_MONTH'): -0.00026983641980064956,
#  ('QUARTER', 'CLOSE_MA_3', 'YEAR'): -0.0003577598104652976,
#  ('QUARTER', 'CLOSE_MA_3', 'MONTH'): -0.0003582652761921522,
#  ('QUARTER', 'CLOSE_MA_3', 'DAY_OF_MONTH'): -0.00035809410465149205,
#  ('QUARTER', 'CLOSE_MA_3', 'WEEK_OF_MONTH'): -0.00035799008787670985,
#  ('QUARTER', 'YEAR', 'MONTH'): -0.012216696353622446,
#  ('QUARTER', 'YEAR', 'DAY_OF_MONTH'): -0.012173604430222687,
#  ('QUARTER', 'YEAR', 'WEEK_OF_MONTH'): -0.012173391618597268,
#  ('QUARTER', 'MONTH', 'DAY_OF_MONTH'): -0.01619270513362705,
#  ('QUARTER', 'MONTH', 'WEEK_OF_MONTH'): -0.016191888126154293,
#  ('QUARTER', 'DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.016146768623902352,
#  ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1'): -0.00026614021977260034,
#  ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3'): -0.00035962545099889743,
#  ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR'): -0.0004505859343440943,
#  ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'MONTH'): -0.0004518737189252558,
#  ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'DAY_OF_MONTH'): -0.000452038937356918,
#  ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'WEEK_OF_MONTH'): -0.0004517422681264816,
#  ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3'): -0.00026706204742859695,
#  ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR'): -0.0002659310066750148,
#  ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'MONTH'): -0.00026626529108760857,
#  ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'DAY_OF_MONTH'): -0.0002659451431738802,
#  ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'WEEK_OF_MONTH'): -0.0002656783747729355,
#  ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR'): -0.00036012634545899133,
#  ('CLOSE_LAG_2', 'CLOSE_MA_3', 'MONTH'): -0.000359632162811134,
#  ('CLOSE_LAG_2', 'CLOSE_MA_3', 'DAY_OF_MONTH'): -0.00035994818172065975,
#  ('CLOSE_LAG_2', 'CLOSE_MA_3', 'WEEK_OF_MONTH'): -0.0003598927391935462,
#  ('CLOSE_LAG_2', 'YEAR', 'MONTH'): -0.0004497664736722208,
#  ('CLOSE_LAG_2', 'YEAR', 'DAY_OF_MONTH'): -0.00045109678217464575,
#  ('CLOSE_LAG_2', 'YEAR', 'WEEK_OF_MONTH'): -0.0004508102730120873,
#  ('CLOSE_LAG_2', 'MONTH', 'DAY_OF_MONTH'): -0.0004523244801556945,
#  ('CLOSE_LAG_2', 'MONTH', 'WEEK_OF_MONTH'): -0.000451999876221236,
#  ('CLOSE_LAG_2', 'DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.0004516328814132744,
#  ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3'): -0.0002673881304612763,
#  ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR'): -0.00026972966117717266,
#  ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH'): -0.000270201260562186,
#  ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'DAY_OF_MONTH'): -0.00026999719200359327,
#  ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'WEEK_OF_MONTH'): -0.00026976777872758065,
#  ('DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR'): -0.00035842966890151583,
#  ('DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH'): -0.0003579333482187459,
#  ('DAY_OF_WEEK', 'CLOSE_MA_3', 'DAY_OF_MONTH'): -0.0003583229348509513,
#  ('DAY_OF_WEEK', 'CLOSE_MA_3', 'WEEK_OF_MONTH'): -0.0003582260454086828,
#  ('DAY_OF_WEEK', 'YEAR', 'MONTH'): -0.01207735583548605,
#  ('DAY_OF_WEEK', 'YEAR', 'DAY_OF_MONTH'): -0.011671898474726394,
#  ('DAY_OF_WEEK', 'YEAR', 'WEEK_OF_MONTH'): -0.011671697041791336,
#  ('DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH'): -0.016076724584577644,
#  ('DAY_OF_WEEK', 'MONTH', 'WEEK_OF_MONTH'): -0.016075916278019648,
#  ('DAY_OF_WEEK', 'DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.015680773036564764,
#  ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR'): -0.0002671752538085101,
#  ('CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH'): -0.00026754783058218374,
#  ('CLOSE_LAG_1', 'CLOSE_MA_3', 'DAY_OF_MONTH'): -0.00026720168243989724,
#  ('CLOSE_LAG_1', 'CLOSE_MA_3', 'WEEK_OF_MONTH'): -0.0002669650003755804,
#  ('CLOSE_LAG_1', 'YEAR', 'MONTH'): -0.00026941314152248506,
#  ('CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH'): -0.0002695743071186646,
#  ('CLOSE_LAG_1', 'YEAR', 'WEEK_OF_MONTH'): -0.00026934697583201443,
#  ('CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH'): -0.00027000873699647683,
#  ('CLOSE_LAG_1', 'MONTH', 'WEEK_OF_MONTH'): -0.0002697622504400728,
#  ('CLOSE_LAG_1', 'DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.0002695943592565317,
#  ('CLOSE_MA_3', 'YEAR', 'MONTH'): -0.0003578304156451127,
#  ('CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH'): -0.000358820004743366,
#  ('CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH'): -0.0003587267541587152,
#  ('CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH'): -0.0003582773915346032,
#  ('CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH'): -0.0003581503667934466,
#  ('CLOSE_MA_3', 'DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.00035817747192891315,
#  ('YEAR', 'MONTH', 'DAY_OF_MONTH'): -0.012077069008672838,
#  ('YEAR', 'MONTH', 'WEEK_OF_MONTH'): -0.012076675501330101,
#  ('YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.011669410425063318,
#  ('MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.016072126998331198,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1'): -0.00026641060460569615,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3'): -0.0003595612194499428,
#  ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR'): -0.00045003824741609064,
#  ('QUARTER', 'CLOSE_LAG_2', 'DAY_OF_WEEK', 'MONTH'): -0.00045269928759367596,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'DAY_OF_MONTH'): -0.0004525075094925111,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'WEEK_OF_MONTH'): -0.0004522182530520734,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3'): -0.0002672904193935285,
#  ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR'): -0.0002659085860678935,
#  ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_LAG_1', 'MONTH'): -0.00026674252025766425,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH'): -0.0002661931580333883,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'WEEK_OF_MONTH'): -0.0002659303474537634,
#  ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR'): -0.0003596617452857038,
#  ('QUARTER', 'CLOSE_LAG_2', 'CLOSE_MA_3', 'MONTH'): -0.00036000558275615723,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.00035987395324048614,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.00035981982601740036,
#  ('QUARTER', 'CLOSE_LAG_2', 'YEAR', 'MONTH'): -0.00045079532605444916,
#  ('QUARTER', 'CLOSE_LAG_2', 'YEAR', 'DAY_OF_MONTH'): -0.00045054418737431505,
#  ('QUARTER', 'CLOSE_LAG_2', 'YEAR', 'WEEK_OF_MONTH'): -0.0004502858281670009,
#  ('QUARTER', 'CLOSE_LAG_2', 'MONTH', 'DAY_OF_MONTH'): -0.0004531120876726361,
#  ('QUARTER', 'CLOSE_LAG_2', 'MONTH', 'WEEK_OF_MONTH'): -0.00045282210629162857,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0004521246180389307,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3'): -0.00026768906609512166,
#  ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR'): -0.00026960325991649684,
#  ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'MONTH'): -0.0002706285953231765,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH'): -0.0002701278829389113,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'WEEK_OF_MONTH'): -0.00026990235749556525,
#  ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR'): -0.0003578990762592576,
#  ('QUARTER', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'MONTH'): -0.00035839037969099614,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.0003582274126292035,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.0003581326773093044,
#  ('QUARTER', 'DAY_OF_WEEK', 'YEAR', 'MONTH'): -0.012219915031415767,
#  ('QUARTER', 'DAY_OF_WEEK', 'YEAR', 'DAY_OF_MONTH'): -0.012176253333869552,
#  ('QUARTER', 'DAY_OF_WEEK', 'YEAR', 'WEEK_OF_MONTH'): -0.012176022011224237,
#  ('QUARTER', 'DAY_OF_WEEK', 'MONTH', 'DAY_OF_MONTH'): -0.01619556584872405,
#  ('QUARTER', 'DAY_OF_WEEK', 'MONTH', 'WEEK_OF_MONTH'): -0.016194741872287165,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.01614913825611412,
#  ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR'): -0.00026718658219562893,
#  ('QUARTER', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH'): -0.0002680188289049572,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.00026748539019134416,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.00026725202578661123,
#  ('QUARTER', 'CLOSE_LAG_1', 'YEAR', 'MONTH'): -0.00026993167591811526,
#  ('QUARTER', 'CLOSE_LAG_1', 'YEAR', 'DAY_OF_MONTH'): -0.00026943584708741237,
#  ('QUARTER', 'CLOSE_LAG_1', 'YEAR', 'WEEK_OF_MONTH'): -0.0002692214383198165,
#  ('QUARTER', 'CLOSE_LAG_1', 'MONTH', 'DAY_OF_MONTH'): -0.00027041148436543624,
#  ('QUARTER', 'CLOSE_LAG_1', 'MONTH', 'WEEK_OF_MONTH'): -0.0002701829311110951,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002697330434491812,
#  ('QUARTER', 'CLOSE_MA_3', 'YEAR', 'MONTH'): -0.0003584891763172433,
#  ('QUARTER', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH'): -0.00035829421804776734,
#  ('QUARTER', 'CLOSE_MA_3', 'YEAR', 'WEEK_OF_MONTH'): -0.0003582202034256396,
#  ('QUARTER', 'CLOSE_MA_3', 'MONTH', 'DAY_OF_MONTH'): -0.0003586997209214731,
#  ('QUARTER', 'CLOSE_MA_3', 'MONTH', 'WEEK_OF_MONTH'): -0.0003586072601284181,
#  ('QUARTER',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00035809105981358697,
#  ('QUARTER', 'YEAR', 'MONTH', 'DAY_OF_MONTH'): -0.01221800147821154,
#  ('QUARTER', 'YEAR', 'MONTH', 'WEEK_OF_MONTH'): -0.012217722300226622,
#  ('QUARTER', 'YEAR', 'DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.012173594652692828,
#  ('QUARTER', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.016190808003566252,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3'): -0.00026714375981341007,
#  ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR'): -0.0002660066094202216,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH'): -0.0002663337560175639,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH'): -0.000266012358659735,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'WEEK_OF_MONTH'): -0.0002657545729281763,
#  ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR'): -0.0003602717120804098,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH'): -0.00035976311681038193,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.0003600884118055164,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.000360042248220021,
#  ('CLOSE_LAG_2', 'DAY_OF_WEEK', 'YEAR', 'MONTH'): -0.00044992889934163333,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00045127034344476463,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00045099414453202494,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.000452485833206366,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0004521714870355942,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0004518188076092917,
#  ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR'): -0.00026685093614643257,
#  ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'MONTH'): -0.0002672260103986811,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.0002670346160547218,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.0002667733859054362,
#  ('CLOSE_LAG_2', 'CLOSE_LAG_1', 'YEAR', 'MONTH'): -0.0002657799789478174,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.0002658340593056748,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00026557779988802834,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026612588862934673,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026584996149049776,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026557233408136636,
#  ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'MONTH'): -0.00035975145475290385,
#  ('CLOSE_LAG_2', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH'): -0.0003606380624095175,
#  ('CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.0003605960982319863,
#  ('CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00036008089773304007,
#  ('CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0003600041699436872,
#  ('CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00036000480965843267,
#  ('CLOSE_LAG_2', 'YEAR', 'MONTH', 'DAY_OF_MONTH'): -0.0004504554228902076,
#  ('CLOSE_LAG_2', 'YEAR', 'MONTH', 'WEEK_OF_MONTH'): -0.0004501641547657186,
#  ('CLOSE_LAG_2',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.000450906323649238,
#  ('CLOSE_LAG_2',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00045200258356399353,
#  ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR'): -0.0002672528512470804,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH'): -0.00026761760651171834,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.000267271009594367,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.00026704364435976716,
#  ('DAY_OF_WEEK', 'CLOSE_LAG_1', 'YEAR', 'MONTH'): -0.0002694757072913374,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.0002696335557159016,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00026941573893388767,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0002700623021349621,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002698253054483449,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002696802268406854,
#  ('DAY_OF_WEEK', 'CLOSE_MA_3', 'YEAR', 'MONTH'): -0.00035797078877271066,
#  ('DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00035897057504669566,
#  ('DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00035888706500854744,
#  ('DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0003584136683193032,
#  ('DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0003582961184782563,
#  ('DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00035833626304643495,
#  ('DAY_OF_WEEK', 'YEAR', 'MONTH', 'DAY_OF_MONTH'): -0.012079047795710526,
#  ('DAY_OF_WEEK', 'YEAR', 'MONTH', 'WEEK_OF_MONTH'): -0.012078635526324846,
#  ('DAY_OF_WEEK',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.011671467067274493,
#  ('DAY_OF_WEEK',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.016074174699965138,
#  ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'MONTH'): -0.00026706294371738217,
#  ('CLOSE_LAG_1', 'CLOSE_MA_3', 'YEAR', 'DAY_OF_MONTH'): -0.0002670927323029185,
#  ('CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00026686618826275824,
#  ('CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0002674225792120398,
#  ('CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026717616280277554,
#  ('CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026687955877139713,
#  ('CLOSE_LAG_1', 'YEAR', 'MONTH', 'DAY_OF_MONTH'): -0.0002693208250142217,
#  ('CLOSE_LAG_1', 'YEAR', 'MONTH', 'WEEK_OF_MONTH'): -0.00026909068630493306,
#  ('CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026925571181801006,
#  ('CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026963384104655263,
#  ('CLOSE_MA_3', 'YEAR', 'MONTH', 'DAY_OF_MONTH'): -0.0003583781984128386,
#  ('CLOSE_MA_3', 'YEAR', 'MONTH', 'WEEK_OF_MONTH'): -0.00035827548606687286,
#  ('CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003588433735931739,
#  ('CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003582111729649423,
#  ('YEAR', 'MONTH', 'DAY_OF_MONTH', 'WEEK_OF_MONTH'): -0.01207527144493306,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3'): -0.00026736538540930564,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR'): -0.0002659772502548258,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH'): -0.0002668078981029673,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH'): -0.0002662549128544074,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'WEEK_OF_MONTH'): -0.0002660008000089799,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR'): -0.00035979344281535027,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH'): -0.00036012421988740475,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.0003599998778185568,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.00035995451519987696,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'MONTH'): -0.00045094337698838374,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00045070080996310283,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00045045201336757013,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00045325501310373745,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00045297473502825135,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0004522907697687451,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR'): -0.00026678869534446,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH'): -0.00026766811947733784,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.00026724302958294044,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.00026698526643895626,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH'): -0.00026634577878108744,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00026579328989799185,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00026555038109638614,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026657514869003084,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026631810448924417,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002658237881965627,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.0003603183982071357,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00036016576536282874,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00036014114186671056,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0003604084119678752,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0003603649230478568,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003599214528738167,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00045141900001845756,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0004511675399942067,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00045038701717734446,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0004530137040030135,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR'): -0.0002672566894017438,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH'): -0.00026808572600916576,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.0002675485293876393,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.00026732415671342776,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH'): -0.00026999108430333956,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00026949029709838815,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00026928508982744894,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00027046292193455286,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00027024346009978274,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002698139117287987,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.00035861900068596703,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.0003584311956409776,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.0003583662195412368,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00035882254775023147,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0003587391483347785,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003582336671325927,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.012221245182671196,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.012220951752727905,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.01217622188715963,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.01619362618003376,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.00026762355246996933,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.000267090043988948,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.0002668762189231859,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026786672260089336,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002676401318325515,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026716433730969164,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0002698082038827791,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002695990431699476,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002691375795711527,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002701003452294952,
#  ('QUARTER',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0003589828443742848,
#  ('QUARTER',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0003589179506649585,
#  ('QUARTER',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003583316549225223,
#  ('QUARTER',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003588135831266433,
#  ('QUARTER',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.012218478194820137,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR'): -0.00026693097284340064,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH'): -0.00026729856642456655,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.0002671067425657938,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.00026685479981257323,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH'): -0.00026584635507007976,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00026590031189289493,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00026565291046885055,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0002661851155418728,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.000265917880815169,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026566163468244857,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.00035988368561849034,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.0003607805160741246,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.0003607477895809192,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00036020920667281114,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00036014141434402146,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.000360153676449049,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.000450613949029055,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00045033259076970546,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00045109109333084753,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0004521742112542445,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.00026666682189989416,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.0002668501292766857,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.0002665993638501075,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.000267184731401724,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002669145625408899,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002666655449919409,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.000265674276913579,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.000265414429218042,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.000265482546088294,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002657134440422397,
#  ('CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0003602670028750612,
#  ('CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0003602141537975479,
#  ('CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.000360713412628943,
#  ('CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003600741858944733,
#  ('CLOSE_LAG_2',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00045017945616903103,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.0002671306025839808,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00026716084810984874,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00026694350404223184,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026748305427311644,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026724563034434946,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002669710879328197,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026937241953399086,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026915145144674395,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002693401120868002,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002697120832277585,
#  ('DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00035851573460910933,
#  ('DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00035842231742789436,
#  ('DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003590042683514026,
#  ('DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00035835710630310007,
#  ('DAY_OF_WEEK',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.012077215596473553,
#  ('CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0002669748598242069,
#  ('CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026674406673236407,
#  ('CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026679059239952715,
#  ('CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.000267060580128034,
#  ('CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002689735306573352,
#  ('CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003583403066982824,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR'): -0.0002668610629520375,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH'): -0.0002677373157513877,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH'): -0.00026730889839144653,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'WEEK_OF_MONTH'): -0.0002670601332996827,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH'): -0.0002664089906542455,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00026585325821349126,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00026561880796310844,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0002666321449624471,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002663834476087066,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026590618498993147,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.0003604422349347567,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.0003602958146211464,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.0003602797209149867,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00036052534783802005,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0003604904604452033,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.000360055200683286,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00045156435284085744,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0004513221829395062,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00045055411252779896,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0004531648324846269,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.0002671977317442927,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.0002667766462072248,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00026653858709764505,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026760005559173326,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002673486985840949,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002668729913620182,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026620895361777593,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.000265970537077035,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002654618672258015,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002662389015390904,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00036078316483906004,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0003607666635557998,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003602499447102318,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003605615921710411,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0004513830488096721,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.000267688284045625,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00026715136539121737,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.0002669463024580046,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026792520599270235,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002677072350617831,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002672480647839677,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0002698575816618653,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002696572008912944,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002692155277458842,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00027017579968199895,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00035911092940926157,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0003590548612323261,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003584780994452834,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00035894390970634126,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.012221704459677445,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026750556044247934,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002672970734432222,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002668051189436181,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026758214782634246,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026953400528135157,
#  ('QUARTER',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00035913201543218474,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.00026673687052174204,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.0002669207602594306,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.0002666791552198535,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026724804067778117,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002669868653444931,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026676108334672597,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026573179557036,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026548040552411056,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026557065990974167,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026579359951979444,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0003603970668938403,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0003603529808081582,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00036086463854525277,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00036021069178720003,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0004503485757093023,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0002666632977745407,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002664088720794612,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002665028045529457,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002667738597156645,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002652882691524262,
#  ('CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003602865491947226,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026703356379574584,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002668115373811413,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002668807088772831,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002671419607365676,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002690488987621473,
#  ('DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00035848767893889783,
#  ('CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026663787660609735,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH'): -0.0002672642707665103,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH'): -0.00026684025128839977,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'WEEK_OF_MONTH'): -0.00026661095248159205,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0002676608772909168,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002674181261437794,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026696061693147444,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026626416094357574,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.0002660338562477559,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026554189596672225,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.000266316104777157,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0003609058406194306,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00036089771429231036,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003603878945741191,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00036068453407279603,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00045153704704312456,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026716428708079053,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026693122325798776,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002664450006060544,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026725922206583875,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002659074319323404,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00036096805572174767,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026756221950441806,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026736212771680647,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026688647927546874,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026766077649946187,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026960650970610976,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003592677477281147,
#  ('QUARTER',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0002672536783142612,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.00026672443735907775,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026647876974197795,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026659662960238723,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.000266859225441934,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026536616623859966,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003604249213304608,
#  ('CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026627870163031586,
#  ('DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026671697098338903,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH'): -0.0002672227829550354,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'WEEK_OF_MONTH'): -0.00026699809195601546,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.000266529790973435,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026734137766886004,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026598231034287813,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.0003610967872952568,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026685832959169706,
#  ('QUARTER',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.000267329979258332,
#  ('CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026636135517625,
#  ('QUARTER',
#   'CLOSE_LAG_2',
#   'DAY_OF_WEEK',
#   'CLOSE_LAG_1',
#   'CLOSE_MA_3',
#   'YEAR',
#   'MONTH',
#   'DAY_OF_MONTH',
#   'WEEK_OF_MONTH'): -0.00026693763680654914}
